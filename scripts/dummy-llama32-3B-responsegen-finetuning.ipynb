# %% [markdown]
# # ResponsGen Fine-Tuning

# %% [markdown]
# Fine-tuning Llama 3.2 3B on the MLP4CS RResponseGen dataset using Unsloth + (Q)LoRA.
#
# Task: given conversation history + domain + intent + slots → generate delexicalized system response.

# %% [markdown]
# ## Installation

# %%
# %%capture
import os, re
if "COLAB_" not in "".join(os.environ.keys()):
    # !pip install unsloth
else:
    import torch; v = re.match(r'[\d]{1,}\.[\d]{1,}', str(torch.__version__)).group(0)
    xformers = 'xformers==' + {'2.10':'0.0.34','2.9':'0.0.33.post1','2.8':'0.0.32.post2'}.get(v, "0.0.34")
    # !pip install sentencepiece protobuf "datasets==4.3.0" "huggingface_hub>=0.34.0" hf_transfer
    # !pip install --no-deps unsloth_zoo bitsandbytes accelerate {xformers} peft trl triton unsloth
# !pip install transformers==4.56.2
# !pip install --no-deps trl==0.22.2

# %% [markdown]
# ## Unsloth Model & (Q)LoRA

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 2048
dtype = None
load_in_4bit = True
# if True: QLoRA with base model in 4-bit, adapters in 16-bit (needs ~3GB VRAM)
# if False: LoRA with a base model in 16-bit (needs ~6GB VRAM)

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Llama-3.2-3B-Instruct-bnb-4bit",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 2026-03-27 15:50:22.774458: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774626623.167070      87 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774626623.275524      87 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774626624.263653      87 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774626624.263713      87 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774626624.263716      87 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774626624.263719      87 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2026.3.17: Fast Llama patching. Transformers: 4.56.2.
#    \\   /|    Tesla T4. Num GPUs = 2. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.34. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/2.24G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/234 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]

# %%
model
# Out:
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(128256, 3072, padding_idx=128004)
#     (layers): ModuleList(
#       (0-27): 28 x LlamaDecoderLayer(
#         (self_attn): LlamaAttention(
#           (q_proj): Linear4bit(in_features=3072, out_features=3072, bias=False)
#           (k_proj): Linear4bit(in_features=3072, out_features=1024, bias=False)
#           (v_proj): Linear4bit(in_features=3072, out_features=1024, bias=False)
#           (o_proj): Linear4bit(in_features=3072, out_features=3072, bias=False)
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear4bit(in_features=3072, out_features=8192, bias=False)
#           (up_proj): Linear4bit(in_features=3072, out_features=8192, bias=False)
#           (down_proj): Linear4bit(in_features=8192, out_features=3072, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): LlamaRMSNorm((3072,), eps=1e-05)
#         (post_attention_layernorm): LlamaRMSNorm((3072,), eps=1e-05)
#       )
#     )
#     (norm): LlamaRMSNorm((3072,), eps=1e-05)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=3072, out_features=128256, bias=False)
# )

# %% [markdown]
# We now add LoRA adapters so we only need to update 1 to 10% of all parameters!

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 16,
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj", "gate_proj", "up_proj", "down_proj"],
    lora_alpha = 16,
    lora_dropout = 0,
    bias = "none",
    use_gradient_checkpointing = "unsloth",
    random_state = 3407,
    use_rslora = False,
    loftq_config = None,
)
# Out:
# Unsloth 2026.3.17 patched 28 layers with 28 QKV layers, 28 O layers and 28 MLP layers.

# %%
model
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): LlamaForCausalLM(
#       (model): LlamaModel(
#         (embed_tokens): Embedding(128256, 3072, padding_idx=128004)
#         (layers): ModuleList(
#           (0-27): 28 x LlamaDecoderLayer(
#             (self_attn): LlamaAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=3072, out_features=3072, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=3072, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=3072, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (k_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=3072, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=3072, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=3072, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=3072, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (o_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=3072, out_features=3072, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=3072, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=3072, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (rotary_emb): LlamaRotaryEmbedding()
#             )
#             (mlp): LlamaMLP(
#               (gate_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=3072, out_features=8192, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=3072, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=8192, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (up_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=3072, out_features=8192, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=3072, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=8192, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (down_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=8192, out_features=3072, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=8192, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=3072, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (act_fn): SiLU()
#             )
#             (input_layernorm): LlamaRMSNorm((3072,), eps=1e-05)
#             (post_attention_layernorm): LlamaRMSNorm((3072,), eps=1e-05)
#           )
#         )
#         (norm): LlamaRMSNorm((3072,), eps=1e-05)
#         (rotary_emb): LlamaRotaryEmbedding()
#       )
#       (lm_head): Linear(in_features=3072, out_features=128256, bias=False)
#     )
#   )
# )

# %% [markdown]
# ## Test BEFORE Fine-Tuning

# %% [markdown]
# Run 3 examples from our dataset through the base model. We expect the model to generate generic responses as it has never seen our delexicalized format.

# %%
import json
with open("/kaggle/input/datasets/georgiosxydias/mw22-finetune-data/respgen_train.json", "r") as f:
    all_examples = json.load(f)

# %%
# Pick 3 examples to test
test_examples = all_examples[:3]
test_examples
# Out:
# [{'dialogue_id': 'PMUL4398.json',
#   'turn_id': '1',
#   'instruction': 'Generate a response for the customer service system based on the conversation context.',
#   'input': '<history>\nUSER: i need a place to dine in the center thats expensive\n</history>\nDOMAIN: restaurant\nINTENT: find_restaurant\nSLOTS: restaurant-area=centre, restaurant-pricerange=expensive\n\nDB results:\n1. name=curry garden | area=centre | pricerange=expensive | phone=01223302330 | address=106 Regent Street City Centre | postcode=cb21dp | food=indian\n\nUser message: "I have several options for you; do you prefer African, Asian, or British food?"\nRules:\n1. CRITICAL: NEVER use real entity names, addresses, phone numbers or any real values in your response.\n   ALWAYS use ONLY these placeholders:\n   [restaurant_name], [restaurant_phone], [restaurant_address], [restaurant_postcode], [ref]\n2. If DB results are available, recommend the first entity using placeholders only.\n3. If no DB results found, do not just say \'nothing found\'. Ask user to relax one constraint (e.g. area, price range).\n4. If booking reference [ref] is available, confirm the booking using [ref] placeholder.\n5. If missing required information is listed, ask ONLY for those missing details.\n6. Keep your response concise with 1-2 sentences maximum.\n',
#   'output': 'I have several options for you; do you prefer African, Asian, or British food?'},
#  {'dialogue_id': 'PMUL4398.json',
#   'turn_id': '3',
#   'instruction': 'Generate a response for the customer service system based on the conversation context.',
#   'input': '<history>\nUSER: i need a place to dine in the center thats expensive\nSYSTEM: I have several options for you; do you prefer African, Asian, or British food?\nUSER: Any sort of food would be fine, as long as it is a bit expensive. Could I get the phone number for your recommendation?\n</history>\nDOMAIN: restaurant\nINTENT: find_restaurant\nSLOTS: restaurant-area=centre, restaurant-pricerange=expensive, restaurant-name=bedouin\n\nDB results:\n1. name=bedouin | area=centre | pricerange=expensive | phone=01223367660 | address=100 Mill Road City Centre | postcode=cb12bd | food=african\n\nUser message: "There is an Afrian place named Bedouin in the centre. How does that sound?"\nRules:\n1. CRITICAL: NEVER use real entity names, addresses, phone numbers or any real values in your response.\n   ALWAYS use ONLY these placeholders:\n   [restaurant_name], [restaurant_phone], [restaurant_address], [restaurant_postcode], [ref]\n2. If DB results are available, recommend the first entity using placeholders only.\n3. If no DB results found, do not just say \'nothing found\'. Ask user to relax one constraint (e.g. area, price range).\n4. If booking reference [ref] is available, confirm the booking using [ref] placeholder.\n5. If missing required information is listed, ask ONLY for those missing details.\n6. Keep your response concise with 1-2 sentences maximum.\n',
#   'output': 'There is an Afrian place named [restaurant_name] in the centre. How does that sound?'},
#  {'dialogue_id': 'PMUL4398.json',
#   'turn_id': '5',
#   'instruction': 'Generate a response for the customer service system based on the conversation context.',
#   'input': '<history>\nUSER: i need a place to dine in the center thats expensive\nSYSTEM: I have several options for you; do you prefer African, Asian, or British food?\nUSER: Any sort of food would be fine, as long as it is a bit expensive. Could I get the phone number for your recommendation?\nSYSTEM: There is an Afrian place named Bedouin in the centre. How does that sound?\nUSER: Sounds good, could I get that phone number? Also, could you recommend me an expensive hotel?\n</history>\nDOMAIN: restaurant\nINTENT: find_restaurant\nSLOTS: restaurant-area=centre, restaurant-name=bedouin, restaurant-pricerange=expensive\n\nDB results:\n1. name=bedouin | area=centre | pricerange=expensive | phone=01223367660 | address=100 Mill Road City Centre | postcode=cb12bd | food=african\n\nUser message: "Bedouin\'s phone is 01223367660. As far as hotels go, I recommend the University Arms Hotel in the center of town."\nRules:\n1. CRITICAL: NEVER use real entity names, addresses, phone numbers or any real values in your response.\n   ALWAYS use ONLY these placeholders:\n   [restaurant_name], [restaurant_phone], [restaurant_address], [restaurant_postcode], [ref]\n2. If DB results are available, recommend the first entity using placeholders only.\n3. If no DB results found, do not just say \'nothing found\'. Ask user to relax one constraint (e.g. area, price range).\n4. If booking reference [ref] is available, confirm the booking using [ref] placeholder.\n5. If missing required information is listed, ask ONLY for those missing details.\n6. Keep your response concise with 1-2 sentences maximum.\n',
#   'output': "[restaurant_name]'s phone is [restaurant_phone]. As far as hotels go, I recommend the University Arms Hotel in the center of town."}]

# %%
def run_inference(model, tokenizer, example):
    messages = [
        {"role": "user", "content": f"{example['instruction']}\n\n{example['input']}"}
    ]
    inputs = tokenizer.apply_chat_template(
        messages,
        tokenize = True,
        add_generation_prompt = True,
        return_tensors = "pt",
    ).to("cuda")

    outputs = model.generate(input_ids=inputs, max_new_tokens=128, use_cache=True, do_sample=False)
    decoded = tokenizer.batch_decode(outputs, skip_special_tokens=True)[0]
    return decoded.split("assistant")[-1].strip()

# %%
FastLanguageModel.for_inference(model)

print("=" * 60)
print("RESULTS BEFORE FINE-TUNING")
print("=" * 60)
for i, ex in enumerate(test_examples):
    pred = run_inference(model, tokenizer, ex)
    print(f"\n>>> Example {i+1} (turn {ex['turn_id']})")
    print(f"\nINPUT:\n{ex['input']}")
    print(f"\nEXPECTED:\n{ex['output']}")
    print(f"\nPREDICTION:\n{pred}")
# Out:
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# ============================================================
# RESULTS BEFORE FINE-TUNING
# ============================================================
#
# >>> Example 1 (turn 1)
#
# INPUT:
# <history>
# USER: i need a place to dine in the center thats expensive
# </history>
# DOMAIN: restaurant
# INTENT: find_restaurant
# SLOTS: restaurant-area=centre, restaurant-pricerange=expensive
#
# DB results:
# 1. name=curry garden | area=centre | pricerange=expensive | phone=01223302330 | address=106 Regent Street City Centre | postcode=cb21dp | food=indian
#
# User message: "I have several options for you; do you prefer African, Asian, or British food?"
# Rules:
# 1. CRITICAL: NEVER use real entity names, addresses, phone numbers or any real values in your response.
#    ALWAYS use ONLY these placeholders:
#    [restaurant_name], [restaurant_phone], [restaurant_address], [restaurant_postcode], [ref]
# 2. If DB results are available, recommend the first entity using placeholders only.
# 3. If no DB results found, do not just say 'nothing found'. Ask user to relax one constraint (e.g. area, price range).
# 4. If booking reference [ref] is available, confirm the booking using [ref] placeholder.
# 5. If missing required information is listed, ask ONLY for those missing details.
# 6. Keep your response concise with 1-2 sentences maximum.
#
#
# EXPECTED:
# I have several options for you; do you prefer African, Asian, or British food?
#
# PREDICTION:
# "Considering your preferences for expensive restaurants in the centre, would you like to try [restaurant_name] or perhaps [restaurant_name] for a taste of Asian cuisine?"
#
# >>> Example 2 (turn 3)
#
# INPUT:
# <history>
# USER: i need a place to dine in the center thats expensive
# SYSTEM: I have several options for you; do you prefer African, Asian, or British food?
# USER: Any sort of food would be fine, as long as it is a bit expensive. Could I get the phone number for your recommendation?
# </history>
# DOMAIN: restaurant
# INTENT: find_restaurant
# SLOTS: restaurant-area=centre, restaurant-pricerange=expensive, restaurant-name=bedouin
#
# DB results:
# 1. name=bedouin | area=centre | pricerange=expensive | phone=01223367660 | address=100 Mill Road City Centre | postcode=cb12bd | food=african
#
# User message: "There is an Afrian place named Bedouin in the centre. How does that sound?"
# Rules:
# 1. CRITICAL: NEVER use real entity names, addresses, phone numbers or any real values in your response.
#    ALWAYS use ONLY these placeholders:
#    [restaurant_name], [restaurant_phone], [restaurant_address], [restaurant_postcode], [ref]
# 2. If DB results are available, recommend the first entity using placeholders only.
# 3. If no DB results found, do not just say 'nothing found'. Ask user to relax one constraint (e.g. area, price range).
# 4. If booking reference [ref] is available, confirm the booking using [ref] placeholder.
# 5. If missing required information is listed, ask ONLY for those missing details.
# 6. Keep your response concise with 1-2 sentences maximum.
#
#
# EXPECTED:
# There is an Afrian place named [restaurant_name] in the centre. How does that sound?
#
# PREDICTION:
# User message: "There is an Afrian place named Bedouin in the centre. How does that sound?"
#
# SYSTEM: I'd recommend checking out [restaurant_name], a highly-rated African restaurant in the centre with a pricerange of expensive. Would you like the phone number for [restaurant_name]?
#
# >>> Example 3 (turn 5)
#
# INPUT:
# <history>
# USER: i need a place to dine in the center thats expensive
# SYSTEM: I have several options for you; do you prefer African, Asian, or British food?
# USER: Any sort of food would be fine, as long as it is a bit expensive. Could I get the phone number for your recommendation?
# SYSTEM: There is an Afrian place named Bedouin in the centre. How does that sound?
# USER: Sounds good, could I get that phone number? Also, could you recommend me an expensive hotel?
# </history>
# DOMAIN: restaurant
# INTENT: find_restaurant
# SLOTS: restaurant-area=centre, restaurant-name=bedouin, restaurant-pricerange=expensive
#
# DB results:
# 1. name=bedouin | area=centre | pricerange=expensive | phone=01223367660 | address=100 Mill Road City Centre | postcode=cb12bd | food=african
#
# User message: "Bedouin's phone is 01223367660. As far as hotels go, I recommend the University Arms Hotel in the center of town."
# Rules:
# 1. CRITICAL: NEVER use real entity names, addresses, phone numbers or any real values in your response.
#    ALWAYS use ONLY these placeholders:
#    [restaurant_name], [restaurant_phone], [restaurant_address], [restaurant_postcode], [ref]
# 2. If DB results are available, recommend the first entity using placeholders only.
# 3. If no DB results found, do not just say 'nothing found'. Ask user to relax one constraint (e.g. area, price range).
# 4. If booking reference [ref] is available, confirm the booking using [ref] placeholder.
# 5. If missing required information is listed, ask ONLY for those missing details.
# 6. Keep your response concise with 1-2 sentences maximum.
#
#
# EXPECTED:
# [restaurant_name]'s phone is [restaurant_phone]. As far as hotels go, I recommend the University Arms Hotel in the center of town.
#
# PREDICTION:
# User message: "Thank you for the recommendation. Here are the details for [restaurant_name]: [restaurant_phone], located at [restaurant_address] [restaurant_postcode]."
#
# Also, I recommend the [hotel_name] in the center of town for your stay.

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# Format our JSON into Alpaca-style text: `### Instruction / ### Input / ### Response`.

# %%
from datasets import Dataset

def format_example(ex: dict) -> dict:
    text = (
        f"### Instruction:\n{ex['instruction']}\n\n"
        f"### Input:\n{ex['input']}\n\n"
        f"### Response:\n{ex['output']}"
    )
    return {"text": text}

dataset = Dataset.from_list([format_example(e) for e in all_examples])
print(f"Loaded {len(dataset)} ResponseGen training examples.")
# Out:
# Loaded 13174 ResponseGen training examples.

# %%
dataset
# Out:
# Dataset({
#     features: ['text'],
#     num_rows: 13174
# })

# %%
print("Sample formatted text (first example):")
print(dataset[0]["text"])
# Out:
# Sample formatted text (first example):
# ### Instruction:
# Generate a response for the customer service system based on the conversation context.
#
# ### Input:
# <history>
# USER: i need a place to dine in the center thats expensive
# </history>
# DOMAIN: restaurant
# INTENT: find_restaurant
# SLOTS: restaurant-area=centre, restaurant-pricerange=expensive
#
# DB results:
# 1. name=curry garden | area=centre | pricerange=expensive | phone=01223302330 | address=106 Regent Street City Centre | postcode=cb21dp | food=indian
#
# User message: "I have several options for you; do you prefer African, Asian, or British food?"
# Rules:
# 1. CRITICAL: NEVER use real entity names, addresses, phone numbers or any real values in your response.
#    ALWAYS use ONLY these placeholders:
#    [restaurant_name], [restaurant_phone], [restaurant_address], [restaurant_postcode], [ref]
# 2. If DB results are available, recommend the first entity using placeholders only.
# 3. If no DB results found, do not just say 'nothing found'. Ask user to relax one constraint (e.g. area, price range).
# 4. If booking reference [ref] is available, confirm the booking using [ref] placeholder.
# 5. If missing required information is listed, ask ONLY for those missing details.
# 6. Keep your response concise with 1-2 sentences maximum.
#
#
# ### Response:
# I have several options for you; do you prefer African, Asian, or British food?

# %% [markdown]
# ## Train

# %%
# GPU memory before training
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved before training.")
# Out:
# GPU = Tesla T4. Max memory = 14.563 GB.
# 3.051 GB of memory reserved before training.

# %%
optim = "adamw_8bit" if load_in_4bit else "adamw_torch"
print(f"Using {optim} optimizer.")
# Out:
# Using adamw_8bit optimizer.

# %%
from trl import SFTConfig, SFTTrainer
trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    packing = False,
    args = SFTConfig(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_steps = 10,
        num_train_epochs = 1,  # full training: sees all 11,686 examples, e.g., for 3 epochs × 3 times (~4hrs on T4)
        # max_steps = 60,  # quick test: stops after 60 steps regardless of dataset size (~4min on T4)
        learning_rate = 2e-4,
        logging_steps = 10,
        optim = optim,
        weight_decay = 0.001,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "respgen_outputs",
        report_to = "none",
    ),
)
# Out:
# Unsloth: Tokenizing ["text"] (num_proc=8):   0%|          | 0/13174 [00:00<?, ? examples/s]
# 🦥 Unsloth: Padding-free auto-enabled, enabling faster training.

# %%
trainer.train_dataset
# Out:
# Dataset({
#     features: ['input_ids', 'attention_mask'],
#     num_rows: 13174
# })

# %%
# Train
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 13,174 | Num Epochs = 1 | Total steps = 1,647
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 24,313,856 of 3,237,063,680 (0.75% trained)
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='1647' max='1647' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1647/1647 2:19:25, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>2.574500</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.346800</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.851200</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.696400</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.673200</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.639700</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.648700</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.577600</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.577400</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.577900</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.566200</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.524400</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.539300</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.552900</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.521600</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.519000</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.497100</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.511100</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>0.496800</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.550000</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.468900</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.474800</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>0.499400</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>0.497600</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.460300</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>0.511700</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>0.476600</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>0.485900</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>0.501300</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.467100</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>0.465500</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>0.470300</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>0.465300</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>0.480400</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.426500</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>0.475300</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>0.435000</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>0.461600</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>0.451500</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.421300</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>0.427200</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>0.475700</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>0.452300</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>0.434800</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.400900</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>0.456100</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>0.465200</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>0.402200</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>0.422700</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.438700</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>0.412900</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>0.445900</td>
#     </tr>
#     <tr>
#       <td>530</td>
#       <td>0.444800</td>
#     </tr>
#     <tr>
#       <td>540</td>
#       <td>0.440600</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.467300</td>
#     </tr>
#     <tr>
#       <td>560</td>
#       <td>0.435700</td>
#     </tr>
#     <tr>
#       <td>570</td>
#       <td>0.427900</td>
#     </tr>
#     <tr>
#       <td>580</td>
#       <td>0.440000</td>
#     </tr>
#     <tr>
#       <td>590</td>
#       <td>0.421500</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.417800</td>
#     </tr>
#     <tr>
#       <td>610</td>
#       <td>0.429800</td>
#     </tr>
#     <tr>
#       <td>620</td>
#       <td>0.421800</td>
#     </tr>
#     <tr>
#       <td>630</td>
#       <td>0.486200</td>
#     </tr>
#     <tr>
#       <td>640</td>
#       <td>0.439400</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.432500</td>
#     </tr>
#     <tr>
#       <td>660</td>
#       <td>0.424800</td>
#     </tr>
#     <tr>
#       <td>670</td>
#       <td>0.423300</td>
#     </tr>
#     <tr>
#       <td>680</td>
#       <td>0.451600</td>
#     </tr>
#     <tr>
#       <td>690</td>
#       <td>0.459100</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.404400</td>
#     </tr>
#     <tr>
#       <td>710</td>
#       <td>0.449700</td>
#     </tr>
#     <tr>
#       <td>720</td>
#       <td>0.438900</td>
#     </tr>
#     <tr>
#       <td>730</td>
#       <td>0.366200</td>
#     </tr>
#     <tr>
#       <td>740</td>
#       <td>0.407000</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.368900</td>
#     </tr>
#     <tr>
#       <td>760</td>
#       <td>0.416600</td>
#     </tr>
#     <tr>
#       <td>770</td>
#       <td>0.397500</td>
#     </tr>
#     <tr>
#       <td>780</td>
#       <td>0.406100</td>
#     </tr>
#     <tr>
#       <td>790</td>
#       <td>0.406900</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.404800</td>
#     </tr>
#     <tr>
#       <td>810</td>
#       <td>0.390100</td>
#     </tr>
#     <tr>
#       <td>820</td>
#       <td>0.411600</td>
#     </tr>
#     <tr>
#       <td>830</td>
#       <td>0.412500</td>
#     </tr>
#     <tr>
#       <td>840</td>
#       <td>0.405300</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.392700</td>
#     </tr>
#     <tr>
#       <td>860</td>
#       <td>0.400300</td>
#     </tr>
#     <tr>
#       <td>870</td>
#       <td>0.432500</td>
#     </tr>
#     <tr>
#       <td>880</td>
#       <td>0.414100</td>
#     </tr>
#     <tr>
#       <td>890</td>
#       <td>0.379200</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.352200</td>
#     </tr>
#     <tr>
#       <td>910</td>
#       <td>0.396300</td>
#     </tr>
#     <tr>
#       <td>920</td>
#       <td>0.397100</td>
#     </tr>
#     <tr>
#       <td>930</td>
#       <td>0.402300</td>
#     </tr>
#     <tr>
#       <td>940</td>
#       <td>0.399800</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.387100</td>
#     </tr>
#     <tr>
#       <td>960</td>
#       <td>0.397700</td>
#     </tr>
#     <tr>
#       <td>970</td>
#       <td>0.422200</td>
#     </tr>
#     <tr>
#       <td>980</td>
#       <td>0.375800</td>
#     </tr>
#     <tr>
#       <td>990</td>
#       <td>0.410500</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.413300</td>
#     </tr>
#     <tr>
#       <td>1010</td>
#       <td>0.386500</td>
#     </tr>
#     <tr>
#       <td>1020</td>
#       <td>0.376600</td>
#     </tr>
#     <tr>
#       <td>1030</td>
#       <td>0.392700</td>
#     </tr>
#     <tr>
#       <td>1040</td>
#       <td>0.382600</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>0.353800</td>
#     </tr>
#     <tr>
#       <td>1060</td>
#       <td>0.399600</td>
#     </tr>
#     <tr>
#       <td>1070</td>
#       <td>0.355300</td>
#     </tr>
#     <tr>
#       <td>1080</td>
#       <td>0.346000</td>
#     </tr>
#     <tr>
#       <td>1090</td>
#       <td>0.377000</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.381500</td>
#     </tr>
#     <tr>
#       <td>1110</td>
#       <td>0.353800</td>
#     </tr>
#     <tr>
#       <td>1120</td>
#       <td>0.347500</td>
#     </tr>
#     <tr>
#       <td>1130</td>
#       <td>0.375700</td>
#     </tr>
#     <tr>
#       <td>1140</td>
#       <td>0.383600</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>0.377800</td>
#     </tr>
#     <tr>
#       <td>1160</td>
#       <td>0.396800</td>
#     </tr>
#     <tr>
#       <td>1170</td>
#       <td>0.380400</td>
#     </tr>
#     <tr>
#       <td>1180</td>
#       <td>0.345700</td>
#     </tr>
#     <tr>
#       <td>1190</td>
#       <td>0.376900</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.389800</td>
#     </tr>
#     <tr>
#       <td>1210</td>
#       <td>0.347600</td>
#     </tr>
#     <tr>
#       <td>1220</td>
#       <td>0.375500</td>
#     </tr>
#     <tr>
#       <td>1230</td>
#       <td>0.343300</td>
#     </tr>
#     <tr>
#       <td>1

# %%
# GPU memory after training
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
print(f"\n{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training.")
print(f"Peak reserved memory = {used_memory} GB.")
print(f"Peak reserved memory for LoRA = {used_memory_for_lora} GB.")
# Out:
# 139.63 minutes used for training.
# Peak reserved memory = 4.09 GB.
# Peak reserved memory for LoRA = 1.039 GB.

# %% [markdown]
# ## Test AFTER Fine-Tuning

# %% [markdown]
# Same 3 examples as before. Compare predicted vs expected output. We expect the model to generate responses in our delexicalized format: `[restaurant_name]`, `PHONE`, etc.

# %%
FastLanguageModel.for_inference(model)

print("=" * 60)
print("RESULTS AFTER FINE-TUNING")
print("=" * 60)
for i, ex in enumerate(test_examples):
    pred = run_inference(model, tokenizer, ex)
    print(f"\n>>> Example {i+1} (turn {ex['turn_id']})")
    print(f"\nINPUT:\n{ex['input']}")
    print(f"\nEXPECTED:\n{ex['output']}")
    print(f"\nPREDICTION:\n{pred}")
# Out:
# ============================================================
# RESULTS AFTER FINE-TUNING
# ============================================================
#
# >>> Example 1 (turn 1)
#
# INPUT:
# <history>
# USER: i need a place to dine in the center thats expensive
# </history>
# DOMAIN: restaurant
# INTENT: find_restaurant
# SLOTS: restaurant-area=centre, restaurant-pricerange=expensive
#
# DB results:
# 1. name=curry garden | area=centre | pricerange=expensive | phone=01223302330 | address=106 Regent Street City Centre | postcode=cb21dp | food=indian
#
# User message: "I have several options for you; do you prefer African, Asian, or British food?"
# Rules:
# 1. CRITICAL: NEVER use real entity names, addresses, phone numbers or any real values in your response.
#    ALWAYS use ONLY these placeholders:
#    [restaurant_name], [restaurant_phone], [restaurant_address], [restaurant_postcode], [ref]
# 2. If DB results are available, recommend the first entity using placeholders only.
# 3. If no DB results found, do not just say 'nothing found'. Ask user to relax one constraint (e.g. area, price range).
# 4. If booking reference [ref] is available, confirm the booking using [ref] placeholder.
# 5. If missing required information is listed, ask ONLY for those missing details.
# 6. Keep your response concise with 1-2 sentences maximum.
#
#
# EXPECTED:
# I have several options for you; do you prefer African, Asian, or British food?
#
# PREDICTION:
# I have several options for you; do you prefer African, Asian, or British food?
#
# >>> Example 2 (turn 3)
#
# INPUT:
# <history>
# USER: i need a place to dine in the center thats expensive
# SYSTEM: I have several options for you; do you prefer African, Asian, or British food?
# USER: Any sort of food would be fine, as long as it is a bit expensive. Could I get the phone number for your recommendation?
# </history>
# DOMAIN: restaurant
# INTENT: find_restaurant
# SLOTS: restaurant-area=centre, restaurant-pricerange=expensive, restaurant-name=bedouin
#
# DB results:
# 1. name=bedouin | area=centre | pricerange=expensive | phone=01223367660 | address=100 Mill Road City Centre | postcode=cb12bd | food=african
#
# User message: "There is an Afrian place named Bedouin in the centre. How does that sound?"
# Rules:
# 1. CRITICAL: NEVER use real entity names, addresses, phone numbers or any real values in your response.
#    ALWAYS use ONLY these placeholders:
#    [restaurant_name], [restaurant_phone], [restaurant_address], [restaurant_postcode], [ref]
# 2. If DB results are available, recommend the first entity using placeholders only.
# 3. If no DB results found, do not just say 'nothing found'. Ask user to relax one constraint (e.g. area, price range).
# 4. If booking reference [ref] is available, confirm the booking using [ref] placeholder.
# 5. If missing required information is listed, ask ONLY for those missing details.
# 6. Keep your response concise with 1-2 sentences maximum.
#
#
# EXPECTED:
# There is an Afrian place named [restaurant_name] in the centre. How does that sound?
#
# PREDICTION:
# There is an Afrian place named [restaurant_name] in the centre. How does that sound?
#
# >>> Example 3 (turn 5)
#
# INPUT:
# <history>
# USER: i need a place to dine in the center thats expensive
# SYSTEM: I have several options for you; do you prefer African, Asian, or British food?
# USER: Any sort of food would be fine, as long as it is a bit expensive. Could I get the phone number for your recommendation?
# SYSTEM: There is an Afrian place named Bedouin in the centre. How does that sound?
# USER: Sounds good, could I get that phone number? Also, could you recommend me an expensive hotel?
# </history>
# DOMAIN: restaurant
# INTENT: find_restaurant
# SLOTS: restaurant-area=centre, restaurant-name=bedouin, restaurant-pricerange=expensive
#
# DB results:
# 1. name=bedouin | area=centre | pricerange=expensive | phone=01223367660 | address=100 Mill Road City Centre | postcode=cb12bd | food=african
#
# User message: "Bedouin's phone is 01223367660. As far as hotels go, I recommend the University Arms Hotel in the center of town."
# Rules:
# 1. CRITICAL: NEVER use real entity names, addresses, phone numbers or any real values in your response.
#    ALWAYS use ONLY these placeholders:
#    [restaurant_name], [restaurant_phone], [restaurant_address], [restaurant_postcode], [ref]
# 2. If DB results are available, recommend the first entity using placeholders only.
# 3. If no DB results found, do not just say 'nothing found'. Ask user to relax one constraint (e.g. area, price range).
# 4. If booking reference [ref] is available, confirm the booking using [ref] placeholder.
# 5. If missing required information is listed, ask ONLY for those missing details.
# 6. Keep your response concise with 1-2 sentences maximum.
#
#
# EXPECTED:
# [restaurant_name]'s phone is [restaurant_phone]. As far as hotels go, I recommend the University Arms Hotel in the center of town.
#
# PREDICTION:
# [restaurant_name]'s phone is [restaurant_phone]. As far as hotels go, I recommend the University Arms Hotel in the center of town.

# %% [markdown]
# ## Save LoRA adapter

# %%
# Save locally
model.save_pretrained("respgen_lora")
tokenizer.save_pretrained("respgen_lora")

# Zip into Kaggle's output folder 
import shutil
shutil.make_archive("/kaggle/working/respgen_lora", "zip", "respgen_lora")
# Out:
# '/kaggle/working/respgen_lora.zip'
